# %% [markdown]
# ***Medical Appointment No Shows***

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/KaggleV2-May-2016.csv")
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
df.size
# Out:
# 1547378

# %%
df.count
# Out:
# <bound method DataFrame.count of            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df.isnull().any()
# Out:
# PatientId         False
# AppointmentID     False
# Gender            False
# ScheduledDay      False
# AppointmentDay    False
# Age               False
# Neighbourhood     False
# Scholarship       False
# Hipertension      False
# Diabetes          False
# Alcoholism        False
# Handcap           False
# SMS_received      False
# No-show           False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
for col in['ScheduledDay','AppointmentDay']:
  df[col]=pd.to_datetime(df[col])
df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262962e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679512e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841186e+12        5642494      F 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572134e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596266e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557663e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213493e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775115e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood  Scholarship  \
# ...

# %%
df.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show'],
#       dtype='object')

# %%
df.drop(['PatientId','AppointmentID'],axis=1,inplace=True)
df.head()
# Out:
#   Gender              ScheduledDay            AppointmentDay  Age  \
# 0      F 2016-04-29 18:38:08+00:00 2016-04-29 00:00:00+00:00   62
# 1      M 2016-04-29 16:08:27+00:00 2016-04-29 00:00:00+00:00   56
# 2      F 2016-04-29 16:19:04+00:00 2016-04-29 00:00:00+00:00   62
# 3      F 2016-04-29 17:29:31+00:00 2016-04-29 00:00:00+00:00    8
# 4      F 2016-04-29 16:07:23+00:00 2016-04-29 00:00:00+00:00   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received No-show
# 0        0             0      No
# 1        0             0      No
# 2        0             0      No
# ...

# %%
df['No-show']=df['No-show'].map({'Yes':1,'No':0})
df.head()
# Out:
#   Gender              ScheduledDay            AppointmentDay  Age  \
# 0      F 2016-04-29 18:38:08+00:00 2016-04-29 00:00:00+00:00   62
# 1      M 2016-04-29 16:08:27+00:00 2016-04-29 00:00:00+00:00   56
# 2      F 2016-04-29 16:19:04+00:00 2016-04-29 00:00:00+00:00   62
# 3      F 2016-04-29 17:29:31+00:00 2016-04-29 00:00:00+00:00    8
# 4      F 2016-04-29 16:07:23+00:00 2016-04-29 00:00:00+00:00   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received  No-show
# 0        0             0        0
# 1        0             0        0
# 2        0             0        0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=df,x='Gender',hue='No-show')
plt.title("GENDER V/S NO-SHOW")
plt.show()

# %%
sns.histplot(data=df,x='Age',hue='No-show',bins=30,kde=True)
plt.title("AGE V/S NO-SHOW")
plt.show()

# %%
df['WaitingTime']=(df['AppointmentDay']-df['ScheduledDay']).dt.days
df = df[df['WaitingTime'] >= 0]
df['WaitingTime']
# Out:
# 5          1
# 6          1
# 7          1
# 9          1
# 10         1
#           ..
# 110522    34
# 110523    34
# 110524    40
# 110525    40
# 110526    40
# Name: WaitingTime, Length: 71959, dtype: int64

# %%
df['Weekday']=df['AppointmentDay'].dt.day_name()
df['Weekday']
# Out:
# <ipython-input-77-3254962335>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weekday']=df['AppointmentDay'].dt.day_name()
# 5          Friday
# 6          Friday
# 7          Friday
# 9          Friday
# 10         Friday
#            ...
# 110522    Tuesday
# 110523    Tuesday
# 110524    Tuesday
# 110525    Tuesday
# 110526    Tuesday
# Name: Weekday, Length: 71959, dtype: object

# %%
df['HourScheduled']=df['ScheduledDay'].dt.hour
df['HourScheduled']
# Out:
# <ipython-input-78-362220157>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HourScheduled']=df['ScheduledDay'].dt.hour
# 5          8
# 6         15
# 7         15
# 9         12
# 10        14
#           ..
# 110522     9
# 110523     7
# 110524    16
# 110525    15
# 110526    13
# Name: HourScheduled, Length: 71959, dtype: int32

# %%
sns.boxplot(data=df,x='No-show',y='WaitingTime')
plt.title('WAITING TIME V/S NO SHOW')
plt.show()

# %%
sns.countplot(data=df,x='Weekday',hue='No-show',order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.title('WEEKDAY V/S NO SHOW')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='CMRmap')
plt.title('CORRELATION MATRIX')
plt.show()

# %%
df['No-show'].value_counts(normalize=True).plot.pie(autopct='%1.1f%%',labels=['Show','No-show'],colors=['lightgreen','lightcoral'])
plt.title('CLASS DISTRIBUTION')
plt.ylabel("")
plt.show()
